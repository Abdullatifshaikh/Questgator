# %% [markdown]
# # Scholarships Aggregation

# %%
pip install bs4 requests

# %% [markdown]
# Scraping Scholarships from eduvision:

# %%
def eduvision():
    import requests
    from bs4 import BeautifulSoup

    USER_AGENT = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
    LANGUAGE = "en-US,en;q=0.5"
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT
    session.headers['Accept-Language'] = LANGUAGE
    session.headers['Content-Language'] = LANGUAGE

    name = 'eduvision'
    url = 'https://www.eduvision.edu.pk/scholarships/'
    html = session.get(url).content
    soup = BeautifulSoup(html, 'html.parser')
    counter = 0
    data= dict()
    table = soup.findAll('div',{'class':'flexlist-item'})
    print(len(table))
    for i in table:
        temp = dict()
        x = i.div.findAll('div')
        temp['title']=x[1].h3.text

        x1 = x[1].find('p').text
        x2 = x[1].find_all('p')[1].text

        y=x[1].find('div').find_all('div')

        y1 = y[0].text
        y2 = y[1].text
        y3 = y[2].text
        y4 = y[3].text

        temp['desc'] = "(" + x1 + ") /  ( " + x2 + ") /\n  ( " + "(" + y1 + " / " + y2 + " / " + y3 + " / " + y4 +") ) "
        print(temp['desc'])

        temp['url'] =x[1].h3.find('a')['href']

        data[counter] = temp
        counter = counter +1




    return data

# %% [markdown]
# Scraping Scholarships from scholar_ship_portal:

# %%
def scholarshipportal():
    import requests
    from bs4 import BeautifulSoup

    USER_AGENT = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
    LANGUAGE = "en-US,en;q=0.5"
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT
    session.headers['Accept-Language'] = LANGUAGE
    session.headers['Content-Language'] = LANGUAGE

    name = 'scholarshipportal'
    url = 'https://www.scholarshipportal.com/scholarships/pakistan'
    html = session.get(url).content
    soup = BeautifulSoup(html, 'html.parser')
    counter = 0
    data = dict()
    table = soup.findAll('a', {'class': 'scholarship scholarship__type--list'})
    for i in table:
        temp = dict()
        temp['title'] = i.h3.text
        temp['url'] = "https://www.scholarshipportal.com" + i['href']
        temp['desc'] = ''
        for j in i.ul.findAll('li'):
            temp['desc'] = temp['desc'] + " // "+ j.text
        data[counter] = temp
        counter = counter + 1

    return  data

# %% [markdown]
# Scraping Scholarships from scholarship_positions:

# %%
def scholarship_positions():
    import requests
    from bs4 import BeautifulSoup

    USER_AGENT = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
    LANGUAGE = "en-US,en;q=0.5"
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT
    session.headers['Accept-Language'] = LANGUAGE
    session.headers['Content-Language'] = LANGUAGE

    name = 'scholarship_positions'
    url = 'https://scholarship-positions.com/category/pakistan-scholarships/'
    html = session.get(url).content
    soup = BeautifulSoup(html, 'html.parser')
    counter = 0
    data = dict()
    table = soup.findAll('article')
    for i in table:
        temp = dict()
        temp['title'] = i.header.text.replace('\n','')
        temp['url'] =  i.find('a')['href']
        temp['desc'] = i.find('div',{'class':'entry-content'}).p.text
        data[counter] = temp
        counter = counter + 1

    return data

# %% [markdown]
# Scraping Scholarships from we_make_scholars:

# %%
def we_make_scholars():
    import requests
    from bs4 import BeautifulSoup

    USER_AGENT = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
    LANGUAGE = "en-US,en;q=0.5"
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT
    session.headers['Accept-Language'] = LANGUAGE
    session.headers['Content-Language'] = LANGUAGE

    name = 'we_make_scholars'
    url = 'https://www.wemakescholars.com/scholarships-for-pakistani-students'
    html = session.get(url).content
    soup = BeautifulSoup(html, 'html.parser')
    counter = 0
    data = dict()
    table = soup.findAll('div',{'class':'head-post-title'})
    for i in table:
        temp=dict()
        temp['title']=i.h2.text.replace('\n','')
        temp['url']="https://www.wemakescholars.com/"+i.h2.a['href']
        temp['desc'] = ''

        for j in i.findAll('p',{'class':'text-line'}):
            temp['desc'] = temp['desc'] + " // " + j.text.replace('\n','').replace('\xa0','')

        data[counter] = temp
        counter = counter + 1

    return data

# %% [markdown]
# Execution Of Codes:

# %%
web = "eduvision"

if web == 'eduvision':
    print(eduvision())
elif web == 'scholar_ship_portal':
    print(scholarshipportal())
elif web == 'scholarship_positions':
    print(scholarship_positions())
elif web == 'we_make_scholars':
    print(we_make_scholars())
else:
    print("not selected !!")
# Out:
# 20
# (Levels:  Matric, Inter) /  ( Fields: ) /
#   ( (
# Type
# Local /
# Category
# Need Based /
# Area
# All Pakistan
#  /
# DeadlineAlways Open) )
# (Levels:  Inter, Bachelor, MS/MPhil, Masters, PhD) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline20-09-2021) )
# (Levels:  Matric, Inter, Bachelor, MS/MPhil, Masters, PhD) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# Balochistan
#  /
# Deadline31-12-2021) )
# (Levels:  Matric) /  ( Fields: ) /
#   ( (
# Type
# International /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline15-09-2021) )
# (Levels:  Masters, PhD) /  ( Fields:  Natural Sciences, Agriculture) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline30-09-2021) )
# (Levels:  Masters) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# Punjab
#  /
# Deadline20-09-2021) )
# (Levels:  Bachelor) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline09-09-2021) )
# (Levels:  Bachelor) /  ( Fields:  Engineering & IT, Natural Sciences, Agriculture, Management Sciences) /
#   ( (
# Type
# Local /
# Category
# Need Based /
# Area
# Punjab
#  /
# Deadline28-08-2021) )
# (Levels:  Matric, Inter) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline02-09-2021) )
# (Levels:  Matric) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# All Pakistan
#  /
# Deadline25-08-2021) )
# (Levels:  Masters) /  ( Fields: All Fields) /
#   ( (
# Type
# International /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline02-11-2021) )
# (Levels:  Bachelor) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# All Pakistan
#  /
# Deadline16-08-2021) )
# (Levels:  Matric, Inter, Bachelor, MS/MPhil) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Need Based /
# Area
# All Pakistan
#  /
# Deadline31-10-2021) )
# (Levels:  Masters) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# All Pakistan
#  /
# Deadline15-09-2021) )
# (Levels:  Bachelor) /  ( Fields:  Medical, Engineering & IT, Natural Sciences, Agriculture, Social Sciences) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# All Pakistan
#  /
# Deadline15-09-2021) )
# (Levels:  Masters) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# All Pakistan
#  /
# DeadlineAlways Open) )
# (Levels:  PhD) /  ( Fields:  Engineering & IT, Natural Sciences, Management Sciences) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline02-08-2021) )
# (Levels:  Bachelor) /  ( Fields:  Natural Sciences) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# Punjab
#  /
# Deadline30-07-2021) )
# (Levels:  Bachelor) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit & Need Based /
# Area
# Sindh
#  /
# Deadline30-09-2021) )
# (Levels:  Matric, Inter) /  ( Fields: All Fields) /
#   ( (
# Type
# Local /
# Category
# Merit Based /
# Area
# All Pakistan
#  /
# Deadline10-08-2021) )
# {0: {'title': ' Ehsaas Education Stipend from primary to Inter', 'desc': '(Levels:  Matric, Inter) /  ( Fields: ) /\n  ( (\nType\nLocal / \nCategory\nNeed Based / \nArea\nAll Pakistan\n / \nDeadlineAlways Open) ) ', 'url': 'ehsaas-education-stipend-from-primary-to-inter-scholar-726'}, 1: {'title': ' State Bank of Pakistan SBP Merit Scholarship', 'desc': '(Levels:  Inter, Bachelor, MS/MPhil, Masters, PhD) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit Based / \nArea\nAll Pakistan\n / \nDeadline20-09-2021) ) ', 'url': 'state-bank-of-pakistan-sbp-merit-scholarship-scholar-205'}, 2: {'title': ' BEEF announces 8000 scholarships for Matric to MS Level', 'desc': '(Levels:  Matric, Inter, Bachelor, MS/MPhil, Masters, PhD) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit & Need Based / \nArea\nBalochistan\n / \nDeadline31-12-2021) ) ', 'url': 'beef-announces-8000-scholarships-for-matric-to-ms-level-scholar-51'}, 3: {'title': ' YES USA Youth Exchange and Study program', 'desc': '(Levels:  Matric) /  ( Fields: ) /\n  ( (\nType\nInternational / \nCategory\nMerit Based / \nArea\nAll Pakistan\n / \nDeadline15-09-2021) ) ', 'url': 'yes-usa-youth-exchange-and-study-program-scholar-633'}, 4: {'title': ' Foreign MS and PhD Scholarships by University of Baltistan ', 'desc': '(Levels:  Masters, PhD) /  ( Fields:  Natural Sciences, Agriculture) /\n  ( (\nType\nLocal / \nCategory\nMerit Based / \nArea\nAll Pakistan\n / \nDeadline30-09-2021) ) ', 'url': 'foreign-ms-and-phd-scholarships-by-university-of-baltistan-scholar-5'}, 5: {'title': ' APWA Punjab Merit Scholarship', 'desc': '(Levels:  Masters) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit Based / \nArea\nPunjab\n / \nDeadline20-09-2021) ) ', 'url': 'apwa-punjab-merit-scholarship-scholar-140'}, 6: {'title': ' CESPI Undergraduate Scholarship', 'desc': '(Levels:  Bachelor) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit Based / \nArea\nAll Pakistan\n / \nDeadline09-09-2021) ) ', 'url': 'cespi-undergraduate-scholarship-scholar-113'}, 7: {'title': ' Interloop Need based scholarship for undergraduate programs', 'desc': '(Levels:  Bachelor) /  ( Fields:  Engineering & IT, Natural Sciences, Agriculture, Management Sciences) /\n  ( (\nType\nLocal / \nCategory\nNeed Based / \nArea\nPunjab\n / \nDeadline28-08-2021) ) ', 'url': 'interloop-need-based-scholarship-for-undergraduate-programs-scholar-678'}, 8: {'title': ' Pakistan Sweet Home Cadet College Scholarship for Orphans', 'desc': '(Levels:  Matric, Inter) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit Based / \nArea\nAll Pakistan\n / \nDeadline02-09-2021) ) ', 'url': 'pakistan-sweet-home-cadet-college-scholarship-for-orphans-scholar-101'}, 9: {'title': ' TNF Akhuwat Foundation Scholarship', 'desc': '(Levels:  Matric) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit & Need Based / \nArea\nAll Pakistan\n / \nDeadline25-08-2021) ) ', 'url': 'tnf-akhuwat-foundation-scholarship-scholar-19'}, 10: {'title': ' British Government Chevening Scholarship for Study in UK', 'desc': '(Levels:  Masters) /  ( Fields: All Fields) /\n  ( (\nType\nInternational / \nCategory\nMerit Based / \nArea\nAll Pakistan\n / \nDeadline02-11-2021) ) ', 'url': 'british-government-chevening-scholarship-for-study-in-uk-scholar-110'}, 11: {'title': ' UNHCR DAFI Scholarship for Afghan Refugee Students ', 'desc': '(Levels:  Bachelor) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nMerit & Need Based / \nArea\nAll Pakistan\n / \nDeadline16-08-2021) ) ', 'url': 'unhcr-dafi-scholarship-for-afghan-refugee-students-scholar-89'}, 12: {'title': ' ALFALAH SCHOLARSHIP SCHEME ', 'desc': '(Levels:  Matric, Inter, Bachelor, MS/MPhil) /  ( Fields: All Fields) /\n  ( (\nType\nLocal / \nCategory\nNeed Based / \nArea\nAll Pakistan\n / \nDeadline31-10-2021) ) ', 'url': 'alfalah-scholarship-scheme-scholar-2'}, 13: {'title': ' Scotland Pakistan Scottish Scholarship for Masters / MPh ...
